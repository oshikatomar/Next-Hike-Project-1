# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Data Acquisition

# %%
df_1 = pd.read_csv("C:\\Users\\This pc\\Desktop\\Oshika\\dataset_1 - dataset_1.csv")
df_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df_2 = pd.read_csv("C:\\Users\\This pc\\Desktop\\Oshika\\dataset_2.xlsx - dataset_2.csv")
df_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df_3 = pd.read_csv("C:\\Users\\This pc\\Desktop\\Oshika\\dataset_3 - dataset_3.csv")
df_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %% [markdown]
# ### Merge Datasets

# %%
# inner - no change, left, right
df_merge = pd.merge(df_1,df_2, on = "instant", how = "inner")
df_merge
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %% [markdown]
# ### Data Wrangling

# %%
df_1.head(3) #This will give first three rows
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22

# %%
df_1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
#This will give first five rows by default of Dataset 2
df_2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
#This will give last five rows by default of Dataset 2
df_2.tail()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
df_1.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
#Identify unique values
df_2.nunique()
# Out:
# Unnamed: 0    610
# instant       610
# atemp          29
# hum            61
# windspeed      20
# casual         32
# registered    150
# cnt           165
# dtype: int64

# %%
df_1.nunique()
# Out:
# instant       610
# dteday         28
# season          1
# yr              1
# mnth            1
# hr             24
# holiday         2
# weekday         7
# weathersit      4
# temp           23
# dtype: int64

# %%
#Check the dimensions of the dataset
df_2.shape
# Out:
# (610, 8)

# %%
df_1.shape
# Out:
# (610, 10)

# %%
#Column Filtering
df2_filtered = df_2[['atemp','hum','casual','registered']]
df2_filtered.head() #This will give the first five rows
# Out:
#     atemp   hum  casual  registered
# 0  0.2879  0.81       3          13
# 1  0.2727  0.80       8          32
# 2  0.2727  0.80       5          27
# 3  0.2879  0.75       3          10
# 4  0.2879  0.75       0           1

# %%
#Rows Filtering
#Select the rows using index
df2_filtered[0:3]
# Out:
#     atemp   hum  casual  registered
# 0  0.2879  0.81       3          13
# 1  0.2727  0.80       8          32
# 2  0.2727  0.80       5          27

# %%
df_2['registered'].mean()
# Out:
# 51.06885245901639

# %%
#Boolean Filtering (Only rows where value 'registered' > the avg. mean value of the column "registered")
df_2[df_2['registered']> df_2['registered'].mean()]
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 12           12       13  0.4242  0.77     0.2836      29          55   84
# 14           14       15  0.4545  0.72     0.2836      35          71  106
# 15           15       16  0.4394  0.77     0.2985      40          70  110
# 16           16       17  0.4242  0.82     0.2985      41          52   93
# 17           17       18     NaN  0.82     0.2836      15          52   67
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 590         590      591  0.2273  0.69     0.0896       3          76   79
# 591         591      592  0.2121  0.74     0.0896       4          55   59
# 601         601      602  0.1970  0.86     0.0896       2          58   60
# 602         602      603  0.1970  0.86     0.0896       2         155  157
# 603         603      604  0.2121  0.86     0.0896       6          95  101
#
# [256 rows x 8 columns]

# %% [markdown]
# ### Describe - Shows most of statistical measures for all the columns

# %%
# Count - Counts the no. of observations in each column, to check missing values
# Mean - gives means
# Std - Gives standard deviation
# min - gives miniumum value for each column
# 25% - value 25% of the dataset
# 50% - gives 50 % value
# 75% - gives 75 % value
# max - gives maximum value for each column
df_merge.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp  Unnamed: 0       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean     0.196885  304.500000    0.199935    0.562475    0.204851    4.501639
# ...

# %%
df_1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %% [markdown]
# ### Calculate the Central Tendecy

# %%
df_2.mean()
# Out:
# Unnamed: 0    304.500000
# instant       305.500000
# atemp           0.199935
# hum             0.562475
# windspeed       0.204851
# casual          4.501639
# registered     51.068852
# cnt            55.570492
# dtype: float64

# %%
df_2.median()
# Out:
# Unnamed: 0    304.500
# instant       305.500
# atemp           0.197
# hum             0.520
# windspeed       0.194
# casual          2.000
# registered     43.000
# cnt            47.000
# dtype: float64

# %%
df_2.mode()
# Out:
#      Unnamed: 0  instant  atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.197  0.47     0.1642     0.0         1.0  1.0
# 1             1        2    NaN   NaN        NaN     NaN         NaN  NaN
# 2             2        3    NaN   NaN        NaN     NaN         NaN  NaN
# 3             3        4    NaN   NaN        NaN     NaN         NaN  NaN
# 4             4        5    NaN   NaN        NaN     NaN         NaN  NaN
# ..          ...      ...    ...   ...        ...     ...         ...  ...
# 605         605      606    NaN   NaN        NaN     NaN         NaN  NaN
# 606         606      607    NaN   NaN        NaN     NaN         NaN  NaN
# 607         607      608    NaN   NaN        NaN     NaN         NaN  NaN
# 608         608      609    NaN   NaN        NaN     NaN         NaN  NaN
# 609         609      610    NaN   NaN        NaN     NaN         NaN  NaN
#
# [610 rows x 8 columns]

# %%
df_2.describe()
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %%
df_merge.mode()
# Out:
#      instant      dteday  season   yr  mnth    hr holiday  weekday  \
# 0          1  01-01-2011     1.0  0.0   1.0  12.0   False      6.0
# 1          2  08-01-2011     NaN  NaN   NaN  13.0     NaN      NaN
# 2          3  09-01-2011     NaN  NaN   NaN  14.0     NaN      NaN
# 3          4  10-01-2011     NaN  NaN   NaN  15.0     NaN      NaN
# 4          5  13-01-2011     NaN  NaN   NaN  16.0     NaN      NaN
# ..       ...         ...     ...  ...   ...   ...     ...      ...
# 605      606         NaN     NaN  NaN   NaN   NaN     NaN      NaN
# 606      607         NaN     NaN  NaN   NaN   NaN     NaN      NaN
# 607      608         NaN     NaN  NaN   NaN   NaN     NaN      NaN
# 608      609         NaN     NaN  NaN   NaN   NaN     NaN      NaN
# 609      610         NaN     NaN  NaN   NaN   NaN     NaN      NaN
#
#      weathersit  temp  Unnamed: 0  atemp   hum  windspeed  casual  registered  \
# 0           1.0   0.2           0  0.197  0.47     0.1642     0.0         1.0
# ...

# %%
df_merge.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# ...

# %%
df_merge.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# ...

# %% [markdown]
# ### Data Wrangling on Dataset 3

# %%
df_3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
df_3.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# ...

# %%
df_3.mode
# Out:
# <bound method DataFrame.mode of      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df_3.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# ...

# %%
df_3.shape
# Out:
# (390, 16)

# %%
df_3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
df_3.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %% [markdown]
# ### Treat missing values

# %%
# Looking for Missing Values
df_2.isnull().sum()
# Out:
# Unnamed: 0     0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Dropping the missing values
# Drop all the missing values
df_2.dropna(inplace = True)
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  599 non-null    int64
#  1   instant     599 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         599 non-null    float64
#  4   windspeed   599 non-null    float64
#  5   casual      599 non-null    int64
#  6   registered  599 non-null    int64
#  7   cnt         599 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 42.1 KB

# %%
# Filling the missing values
df_2.fillna(0,inplace = True)
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  599 non-null    int64
#  1   instant     599 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         599 non-null    float64
#  4   windspeed   599 non-null    float64
#  5   casual      599 non-null    int64
#  6   registered  599 non-null    int64
#  7   cnt         599 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 42.1 KB

# %%
#again run after handelling missing values
df_2.isnull().sum()
# Out:
# Unnamed: 0    0
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Know the Data Type

# %%
df_2.dtypes
# Out:
# Unnamed: 0      int64
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
# Covert One Data Type to Another
df_2['atemp'] = df_2['atemp'].astype("int64")
df_2.dtypes
# Out:
# Unnamed: 0      int64
# instant         int64
# atemp           int64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ### Concatenate with Dataset 3

# %%
dfcon = pd.concat([df_3,df_merge],axis =1, join= "inner")
dfcon
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
dfcon.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp  ...  weekday  weathersit  temp  Unnamed: 0   atemp   hum  windspeed  \
# 0  0.22  ...        6           1  0.24           0  0.2879  0.81        0.0
# 1  0.22  ...        6           1  0.22           1  0.2727  0.80        0.0
# 2  0.20  ...        6           1  0.22           2  0.2727  0.80        0.0
# 3  0.16  ...        6           1  0.24           3  0.2879  0.75        0.0
# 4  0.16  ...        6           1  0.24           4  0.2879  0.75        0.0
#
#   casual  registered  cnt
# ...

# %% [markdown]
# ### skewness and correlation of the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import skew

# %%
dfcon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
#  16  instant     390 non-null    int64
#  17  dteday      390 non-null    object
#  18  season      390 non-null    int64
# ...

# %%
dfcon.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum  ...     weekday  \
# count  390.000000  390.000000  390.000000  390.000000  ...  390.000000
# mean     1.484615    0.220000    0.230424    0.613769  ...    2.920513
# std      0.663805    0.073095    0.069455    0.202361  ...    2.160962
# ...

# %%
dfcon.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# Unnamed: 0      int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df_2.corr()
# Out:
#             Unnamed: 0   instant  atemp       hum  windspeed    casual  \
# Unnamed: 0    1.000000  1.000000    NaN  0.062195  -0.025812 -0.089014
# instant       1.000000  1.000000    NaN  0.062195  -0.025812 -0.089014
# atemp              NaN       NaN    NaN       NaN        NaN       NaN
# hum           0.062195  0.062195    NaN  1.000000  -0.310377 -0.214266
# windspeed    -0.025812 -0.025812    NaN -0.310377   1.000000  0.116519
# casual       -0.089014 -0.089014    NaN -0.214266   0.116519  1.000000
# registered    0.033535  0.033535    NaN -0.226639   0.039875  0.305232
# cnt           0.020589  0.020589    NaN -0.243511   0.052926  0.418961
#
#             registered       cnt
# Unnamed: 0    0.033535  0.020589
# instant       0.033535  0.020589
# atemp              NaN       NaN
# hum          -0.226639 -0.243511
# windspeed     0.039875  0.052926
# casual        0.305232  0.418961
# registered    1.000000  0.992553
# cnt           0.992553  1.000000

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for col in df_2:
    print(col)
    print(skew(df_2[col]))
    
    plt.figure()
    sns.distplot(df_2[col])
    plt.show()
# Out:
# Unnamed: 0
# -0.017776354390488098
# instant
# -0.017776354390488098
# atemp
# nan
# hum
# 0.621323021959802
# windspeed
# 0.3483048815615366
# casual
# 2.7231608540911507
# registered
# 1.4104011867828836
# cnt
# 1.2270845009071916

# %%
# Skewness along the index axis
df_2.skew(axis = 0, skipna = True)
# Out:
# Unnamed: 0   -0.017821
# instant      -0.017821
# atemp         0.000000
# hum           0.622884
# windspeed     0.349180
# casual        2.730002
# registered    1.413944
# cnt           1.230167
# dtype: float64

# %%
# Skip the na values
# find skewnwss in each row
df_2.skew(axis = 1, skipna = True)
# Out:
# 0      1.412466
# 1      1.414756
# 2      1.417521
# 3      1.163339
# 4      1.311829
#          ...
# 605    1.430714
# 606    1.431816
# 607    1.430129
# 608    1.426127
# 609    1.423164
# Length: 599, dtype: float64

# %%
df_2.boxplot (column = 'instant', by = 'windspeed');
